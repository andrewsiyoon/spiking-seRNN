# %% [markdown]
# <a href="https://colab.research.google.com/github/andrewsiyoon/spiking-seRNN/blob/main/DVSGesture_reg-strength_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
pip install tonic

# %%
# %%capture
# !git clone https://github.com/jeshraghian/snntorch
# %cd snntorch
# !python3 setup.py install

# %%
#Imports -----

import torch, torch.nn as nn
import snntorch as snn
import numpy as np
import scipy 
import tonic

import random

import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

import seaborn as sns

# %%
#Random seeds -----

random.seed(211)
torch.manual_seed(211)

# %%
#DVS Gesture -----

import tonic
import tonic.transforms as transforms
from tonic import DiskCachedDataset

from torch.utils.data import DataLoader

#Define variables (batch size, sensor size)
batch_size = 64
data_path = '/data/DVSGesture'
dtype = torch.float
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
sensor_size = tonic.datasets.DVSGesture.sensor_size

#Define transformations
frame_transform = tonic.transforms.Compose([transforms.Denoise(filter_time=10000), transforms.ToFrame(sensor_size=sensor_size, n_time_bins = 20)])

#Define training and test sets
DVS_train = tonic.datasets.DVSGesture(save_to='./data', transform=frame_transform, train=True)
DVS_test = tonic.datasets.DVSGesture(save_to='./data', transform=frame_transform, train=False)

#Create cached sets
cached_trainset = DiskCachedDataset(DVS_train, cache_path='./cache/DVSGesture/train')
cached_testset = DiskCachedDataset(DVS_test, cache_path='./cache/DVSGesture/test')

#Create dataloaders
trainloader = DataLoader(cached_trainset, batch_size=batch_size, collate_fn=tonic.collation.PadTensors(batch_first=False), shuffle=True, drop_last = True)
testloader = DataLoader(cached_testset, batch_size=batch_size, collate_fn=tonic.collation.PadTensors(batch_first=False), drop_last = True)

# %%
#Initialize membrane time constant distribution -----

tau_mem = 20e-3
dist_shape = 3
time_step = 0.5e-3

def clip_tc(x):
    clipped_tc = x.clamp_(0.7165, 0.995)
    return clipped_tc

def init_tc():
    dist_gamma = np.random.gamma(dist_shape, tau_mem / 3, 100)
    dist_beta = torch.from_numpy(np.exp(-time_step / dist_gamma))
    clipped_beta = clip_tc(dist_beta)
    return clipped_beta

# %%
#Model architecture -----

from snntorch import surrogate

#Size parameters
num_inputs = 128*128*2
num_hidden = 100
num_outputs = 11

#Network parameters
het_tau = init_tc().to(device)
hom_tau = 0.9753

#Optimization mechanism
spike_grad = surrogate.fast_sigmoid()

#Model definition
class Net(nn.Module):
    def __init__(self):
        super().__init__()

        #Initialize layers
        self.fc1 = nn.Linear(num_inputs, num_hidden)
        self.lif1 = snn.RLeaky(beta = het_tau, linear_features = num_hidden, learn_beta = True, spike_grad = spike_grad)
        self.fc2 = nn.Linear(num_hidden, num_outputs)
        self.lif2 = snn.Leaky(beta = hom_tau, spike_grad = spike_grad)

    def forward(self, x):

        #Initialize parameters
        spk1, mem1 = self.lif1.init_rleaky() #init_rleaky() creates a tuple [_SpikeTensor, _SpikeTensor], assigns each to mem1 and spk1
        mem2 = self.lif2.init_leaky() #init_leaky() creates a tensor _SpikeTensor 

        #Record final layer
        spk_rec = []
        mem_rec = []

        #Forward loop
        for step in range(data.size(0)): #Iterate over the number of time steps in each mini-batch
            batched_data = data[step].view(batch_size, num_inputs) #Reshape input tensor to [batch_size, num_inputs]
            cur1 = self.fc1(batched_data)
            spk1, mem1 = self.lif1(cur1, spk1, mem1)
            cur2 = self.fc2(spk1)
            spk2, mem2 = self.lif2(cur2, mem2)

            spk_rec.append(spk2)
            mem_rec.append(mem2)

        #Convert final lists to tensors
        spk_rec = torch.stack(spk_rec)
        mem_rec = torch.stack(mem_rec)
        
        return spk_rec, mem_rec

net = Net().to(device)

# %%
#Model visualizations (pre-training) -----  

# #All layers and associated parameters
# for name, param in net.named_parameters():
#     print(f"Layer: {name} | Size: {param.size()} | Values : {param} \n")

#Membrane time constant distribution
#Define plot + parameters
tau = (-time_step / np.log(het_tau.cpu())) / 1e-3
fig, ax = plt.subplots()
tc_distribution = sns.histplot(data = tau, kde = False, ax = ax, binwidth = 3)

#Set x-axis limit and remove y-axis
ax.set_xlim(0,100)
ax.axes.get_yaxis().set_visible(False)
plt.xlabel('ms')
# Out:
# Text(0.5, 0, 'ms')

# %%
#Optimizer and loss function -----

import snntorch.functional as SF

optimizer = torch.optim.Adam(net.parameters(), lr = 1e-3, betas = (0.9, 0.999))
loss_fn = SF.mse_count_loss(correct_rate = 0.8, incorrect_rate = 0.2)

# %%
#Distance matrix -----

network_structure = [5, 5, 4]
distance_metric = 'euclidean'
distance_power = 1

nx = np.arange(network_structure[0])
ny = np.arange(network_structure[1])
nz = np.arange(network_structure[2])

[x,y,z] = np.meshgrid(nx,ny,nz)
coordinates = [x.ravel(),y.ravel(),z.ravel()]

euclidean_vector = scipy.spatial.distance.pdist(np.transpose(coordinates), metric=distance_metric)
euclidean = scipy.spatial.distance.squareform(euclidean_vector**distance_power)
distance_matrix = euclidean.astype('float32')

distance_matrix = torch.from_numpy(distance_matrix).to(device)

# %%
#Diagnostic tests -----

from scipy.stats import pearsonr

#Test for spatial regularization
def test_euclidean(x, y):
    x = torch.abs(x)
    x_array = x.cpu().detach().numpy()
    flat_x_array = x_array.flatten()
    y = torch.abs(y)
    y_array = y.cpu().detach().numpy()
    flat_y_array = y_array.flatten()
    correlation = pearsonr(flat_x_array, flat_y_array)[0]
    return correlation

print(f"Initial correlation between distance and weight matrices: {test_euclidean(distance_matrix, net.lif1.recurrent.weight)}")
# Out:
# Initial correlation between distance and weight matrices: -0.00720281738029272

# %%
#Training paradigm -----

#Training parameters
num_epochs = 100

#Regularization parameters
regu_strength = 1

#Initialize loss, accuracy, mean weights
loss_hist = []
acc_hist = []
feed_tot_hist = []
rec_tot_hist = []
corr_hist = []

#Pre-training extractions
acc_hist.append(0)
feed_tot_hist.append(torch.sum(torch.abs(net.fc1.weight.data)))
rec_tot_hist.append(torch.sum(torch.abs(net.lif1.recurrent.weight.data)))
corr_hist.append(test_euclidean(distance_matrix, net.lif1.recurrent.weight))

#Training loop
for epoch in range(num_epochs):
    for i, (data, targets) in enumerate(iter(trainloader)):

        #Load on CUDA (if available)
        data = data.to(device)
        targets = targets.to(device)

        #Set model to training mode
        net.train()
        outputs, _ = net(data)

        #Spatial + L1 regularization
        abs_weight_matrix = torch.abs(net.lif1.recurrent.weight).to(device)
        spatial_L1_loss = regu_strength * torch.sum(torch.mul(abs_weight_matrix, distance_matrix))

        #Calculate loss
        loss_val = loss_fn(outputs, targets) + spatial_L1_loss

        #Gradient calculation and weight updates
        optimizer.zero_grad()
        loss_val.backward()
        optimizer.step()
        clip_tc(net.lif1.beta.data)

        #Store loss history
        loss_hist.append(loss_val.item())

    #Evaluations (every epoch)
    net.eval()

    #Report training loss
    print(f"Epoch {epoch} \nTraining Loss: {loss_val.item():.2f}")

    #Training accuracy
    acc = SF.accuracy_rate(outputs, targets) #Outputs: [num_steps, batch_size, num_outputs]. Targets: [batch_size]
    acc_hist.append(acc)
    print(f"Training accuracy: {acc * 100:.2f}%")

    #Sum of feedforward weights
    feed_tot = torch.sum(torch.abs(net.fc1.weight.data))
    feed_tot_hist.append(feed_tot)
    print(f"Total feedforward weight: {feed_tot}")

    #Sum of recurrent weights
    rec_tot = torch.sum(torch.abs(net.lif1.recurrent.weight.data))
    rec_tot_hist.append(rec_tot)
    print(f"Total recurrent weight: {rec_tot}")

    #Correlation of distance and weight matrices
    corr_matrices = test_euclidean(distance_matrix, net.lif1.recurrent.weight)
    corr_hist.append(corr_matrices)
    print(f"Correlation of distance and weight matrices: {corr_matrices}\n")
# Out:
# Epoch 0
# Training Loss: 1107.97
# Training accuracy: 31.25%
# Total feedforward weight: 15257.7265625
# Total recurrent weight: 359.487060546875
# Correlation of distance and weight matrices: -0.021274440230774547
#
# Epoch 1
# Training Loss: 740.26
# Training accuracy: 45.31%
# Total feedforward weight: 17786.802734375
# Total recurrent weight: 240.2922821044922
# Correlation of distance and weight matrices: -0.03278658750911452
#
# Epoch 2
# Training Loss: 444.82
# Training accuracy: 51.56%
# Total feedforward weight: 18801.353515625
# Total recurrent weight: 144.9134521484375
# Correlation of distance and weight matrices: -0.0547063821898598
#
# Epoch 3
# Training Loss: 225.05
# Training accuracy: 56.25%
# Total feedforward weight: 19372.546875
# Total recurrent weight: 74.78837585449219
# Correlation of distance and weight matrices: -0.09752397217492093
#
# Epoch 4
# Training Loss: 83.35
# Training accuracy: 60.94%
# Total feedforward weight: 19951.984375
# Total recurrent weight: 29.913406372070312
# Correlation of distance and weight matrices: -0.1698844864255166
#
# Epoch 5
# Training Loss: 20.35
# Training accuracy: 57.81%
# Total feedforward weight: 20495.94921875
# Total recurrent weight: 10.778104782104492
# Correlation of distance and weight matrices: -0.22083364768376568
#
# Epoch 6
# Training Loss: 9.38
# Training accuracy: 60.94%
# Total feedforward weight: 20975.6875
# Total recurrent weight: 7.473325729370117
# Correlation of distance and weight matrices: -0.22181780583909355
#
# Epoch 7
# Training Loss: 5.78
# Training accuracy: 68.75%
# Total feedforward weight: 21436.142578125
# Total recurrent weight: 6.409867763519287
# Correlation of distance and weight matrices: -0.22104803076796747
#
# Epoch 8
# Training Loss: 4.65
# Training accuracy: 60.94%
# Total feedforward weight: 21915.88671875
# Total recurrent weight: 6.044837951660156
# Correlation of distance and weight matrices: -0.22026995380156916
#
# Epoch 9
# Training Loss: 4.29
# Training accuracy: 64.06%
# Total feedforward weight: 22395.193359375
# Total recurrent weight: 5.890124320983887
# Correlation of distance and weight matrices: -0.21809502058838592
#
# Epoch 10
# Training Loss: 4.18
# Training accuracy: 79.69%
# Total feedforward weight: 22876.95703125
# Total recurrent weight: 5.871172904968262
# Correlation of distance and weight matrices: -0.21668598119896654
#
# Epoch 11
# Training Loss: 4.27
# Training accuracy: 64.06%
# Total feedforward weight: 23363.078125
# Total recurrent weight: 5.8479719161987305
# Correlation of distance and weight matrices: -0.2149078253776311
#
# Epoch 12
# Training Loss: 4.19
# Training accuracy: 64.06%
# Total feedforward weight: 23908.5703125
# Total recurrent weight: 5.80363655090332
# Correlation of distance and weight matrices: -0.2137402467124639
#
# Epoch 13
# Training Loss: 4.21
# Training accuracy: 62.50%
# Total feedforward weight: 24391.33984375
# Total recurrent weight: 5.788285732269287
# Correlation of distance and weight matrices: -0.21284683775590885
#
# Epoch 14
# Training Loss: 4.13
# Training accuracy: 73.44%
# Total feedforward weight: 24884.740234375
# Total recurrent weight: 5.756965160369873
# Correlation of distance and weight matrices: -0.211654909703815
#
# Epoch 15
# Training Loss: 4.21
# Training accuracy: 54.69%
# Total feedforward weight: 25366.841796875
# Total recurrent weight: 5.790518283843994
# Correlation of distance and weight matrices: -0.2102647088307041
#
# Epoch 16
# Training Loss: 4.20
# Training accuracy: 64.06%
# Total feedforward weight: 25794.025390625
# Total recurrent weight: 5.794862270355225
# Correlation of distance and weight matrices: -0.20997690806629565
#
# Epoch 17
# Training Loss: 4.13
# Training accuracy: 68.75%
# Total feedforward weight: 26268.71875
# Total recurrent weight: 5.852118492126465
# Correlation of distance and weight matrices: -0.20939976350786227
#
# Epoch 18
# Training Loss: 4.12
# Training accuracy: 81.25%
# Total feedforward weight: 26839.58203125
# Total recurrent weight: 5.867523670196533
# Correlation of distance and weight matrices: -0.20875915709365223
#
# Epoch 19
# Training Loss: 4.12
# Training accuracy: 68.75%
# Total feedforward weight: 27301.58203125
# Total recurrent weight: 5.893308639526367
# Correlation of distance and weight matrices: -0.2089020296786945
#
# Epoch 20
# Training Loss: 4.12
# Training accuracy: 64.06%
# Total feedforward weight: 27671.94921875
# Total recurrent weight: 5.921846389770508
# Correlation of distance and weight matrices: -0.20890697625645066
#
# Epoch 21
# Training Loss: 4.15
# Training accuracy: 76.56%
# Total feedforward weight: 28065.296875
# Total recurrent weight: 5.978104591369629
# Correlation of distance and weight matrices: -0.20938704251029425
#
# Epoch 22
# Training Loss: 4.17
# Training accuracy: 62.50%
# Total feedforward weight: 28464.20703125
# Total recurrent weight: 6.006053447723389
# Correlation of distance and weight matrices: -0.20956580154086757
#
# Epoch 23
# Training Loss: 4.14
# Training accuracy: 60.94%
# Total feedforward weight: 28807.166015625
# Total recurrent weight: 6.021602153778076
# Correlation of distance and weight matrices: -0.20972971807091512
#
# Epoch 24
# Training Loss: 4.04
# Training accuracy: 75.00%
# Total feedforward weight: 29176.333984375
# Total recurrent weight: 6.091283321380615
# Correlation of distance and weight matrices: -0.20951506874054335
#
# Epoch 25
# Training Loss: 4.21
# Training accuracy: 53.12%
# Total feedforward weight: 29581.98828125
# Total recurrent weight: 6.086598873138428
# Correlation of distance and weight matrices: -0.20832195753936436
#
# Epoch 26
# Training Loss: 4.06
# Training accuracy: 75.00%
# Total feedforward weight: 30009.279296875
# Total recurrent weight: 6.116021156311035
# Correlation of distance and weight matrices: -0.20760262318665001
#
# Epoch 27
# Training Loss: 4.12
# Training accuracy: 71.88%
# Total feedforward weight: 30385.58984375
# Total recurrent weight: 6.1645894050598145
# Correlation of distance and weight matrices: -0.20777165457447605
#
# Epoch 28
# Training Loss: 4.09
# Training accuracy: 65.62%
# Total feedforward weight: 30787.875
# Total recurrent weight: 6.178189277648926
# Correlation of distance and weight matrices: -0.20762225697517042
#
# Epoch 29
# Training Loss: 4.09
# Training accuracy: 67.19%
# Total feedforward weight: 31115.7109375
# Total recurrent weight: 6.215980529785156
# Correlation of distance and weight matrices: -0.20768032691273208
#
# Epoch 30
# Training Loss: 4.09
# Training accuracy: 71.88%
# Total feedforward weight: 31423.23046875
# Total recurrent weight: 6.246309280395508
# Correlation of distance and weight matrices: -0.2073569823828272
#
# Epoch 31
# Training Loss: 4.14
# Training accuracy: 56.25%
# Total feedforward weight: 31723.30859375
# Total recurrent weight: 6.290821075439453
# Correlation of distance and weight matrices: -0.2073113624914937
#
# Epoch 32
# Training Loss: 4.17
# Training accuracy: 64.06%
# Total feedforward weight: 31983.59375
# Total recurrent weight: 6.305363178253174
# Correlation of distance and weight matrices: -0.2072981419312587
#
# Epoch 33
# Training Loss: 4.03
# Training accuracy: 82.81%
# Total feedforward weight: 32435.1875
# Total recurrent weight: 6.313387870788574
# Correlation of distance and weight matrices: -0.20714720188932695
#
# Epoch 34
# Training Loss: 4.09
# Training accuracy: 68.75%
# Total feedforward weight: 32801.5
# Total recurrent weight: 6.3418779373168945
# Correlation of distance and weight matrices: -0.206848761505172
#
# Epoch 35
# Training Loss: 4.00
# Training accuracy: 81.25%
# Total feedforward weight: 33157.19921875
# Total recurrent weight: 6.364826202392578
# Correlation of distance and weight matrices: -0.20659168968264724
#
# Epoch 36
# Training Loss: 4.15
# Training accuracy: 81.25%
# Total feedforward weight: 33498.59375
# Total recurrent weight: 6.403614521026611
# Correlation of distance and weight matrices: -0.20701794945392396
#
# Epoch 37
# Training Loss: 4.09
# Training accuracy: 79.69%
# Total feedforward weight: 33792.046875
# Total recurrent weight: 6.406313896179199
# Correlation of distance and weight matrices: -0.20712270757711906
#
# Epoch 38
# Training Loss: 4.05
# Training accuracy: 79.69%
# Total feedforward weight: 34169.1953125
# Total recurrent weight: 6.436797142028809
# Correlation of distance and weight matrices: -0.20805361368107264
#
# Epoch 39
# Training Loss: 4.05
# Training accuracy: 67.19%
# Total feedforward weight: 34490.46484375
# Total recurrent weight: 6.44272518157959
# Correlation of distance and weight matrices: -0.2077310208514032
#
# Epoch 40
# Training Loss: 4.09
# Training accuracy: 68.75%
# Total feedforward weight: 34779.84765625
# Total recurrent weight: 6.489734172821045
# Correlation of distance and weight matrices: -0.20758637861105644
#
# Epoch 41
# Training Loss: 4.08
# Training accuracy: 73.44%
# Total feedforward weight: 35109.8203125
# Total recurrent weight: 6.503073692321777
# Correlation of distance and weight matrices: -0.20728482844506052
#
# Epoch 42
# Training Loss: 4.10
# Training accuracy: 68.75%
# Total feedforward weight: 35387.546875
# Total recurrent weight: 6.537847518920898
# Correlation of distance and weight matrices: -0.20734283757273703
#
# Epoch 43
# Training Loss: 4.14
# Training accuracy: 71.88%
# Total feedforward weight: 35702.16796875
# Total recurrent weight: 6.547554969787598
# Correlation of distance and weight matrices: -0.20708082436801722
#
# Epoch 44
# Training Loss: 4.04
# Training accuracy: 73.44%
# Total feedforward weight: 36119.48828125
# Total recurrent weight: 6.5393781661987305
# Correlation of distance and weight matrices: -0.2059896095174046
#
# Epoch 45
# Training Loss: 4.08
# Training accuracy: 68.75%
# Total feedforward weight: 36480.84375
# Total recurrent weight: 6.593916416168213
# Correlation of distance and weight matrices: -0.20564676548983105
#
# Epoch 46
# Training Loss: 4.05
# Training accuracy: 76.56%
# Total feedforward weight: 36736.83984375
# Total recurrent weight: 6.626091957092285
# Correlation of distance and weight matrices: -0.20531313992154457
#
# Epoch 47
# Training Loss: 4.07
# Training accuracy: 76.56%
# Total feedforward weight: 36988.046875
# Total recurrent weight: 6.634174346923828
# Correlation of distance and weight matrices: -0.20542907725776718
#
# Epoch 48
# Training Loss: 4.05
# Training accuracy: 70.31%
# Total feedforward weight: 37258.8515625
# Total recurrent weight: 6.628256797790527
# Correlation of distance and weight matrices: -0.20545142862161286
#
# Epoch 49
# Training Loss: 4.12
# Training accuracy: 59.38%
# Total feedforward weight: 37565.5546875
# Total recurrent weight: 6.652735710144043
# Correlation of distance and weight matrices: -0.2051790165273752
#
# Epoch 50
# Training Loss: 4.05
# Training accuracy: 85.94%
# Total feedforward weight: 37934.890625
# Total recurrent weight: 6.695116996765137
# Correlation of distance and weight matrices: -0.2056981465036806
#
# Epoch 51
# Training Loss: 4.10
# Training accuracy: 78.12%
# Total feedforward weight: 38297.140625
# Total recurrent weight: 6.720630168914795
# Correlation of distance and weight matrices: -0.20578368830800803
#
# Epoch 52
# Training Loss: 4.13
# Training accuracy: 70.31%
# Total feedforward weight: 38653.40234375
# Total recurrent weight: 6.735066890716553
# Correlation of distance and weight matrices: -0.2058419042127729
#
# Epoch 53
# Training Loss: 4.08
# Training accuracy: 78.12%
# Total feedforward weight: 39003.4609375
# Total recurrent weight: 6.735686779022217
# Correlation of distance and weight matrices: -0.20571253153312344
#
# Epoch 54
# Training Loss: 4.04
# Training accuracy: 59.38%
# Total feedforward weight: 39279.828125
# Total recurrent weight: 6.720263481140137
# Correlation of distance and weight matrices: -0.20575127965074097
#
# Epoch 55
# Training Loss: 4.05
# Training accuracy: 75.00%
# Total feedforward weight: 39498.32421875
# Total recurrent weight: 6.774348735809326
# Correlation of distance and weight matrices: -0.20565918703749386
#
# Epoch 56
# Training Loss: 4.12
# Training accuracy: 71.88%
# Total feedforward weight: 39802.203125
# Total recurrent weight: 6.778524398803711
# Correlation of distance and weight matrices: -0.20589961838511295
#
# Epoch 57
# Training Loss: 4.07
# Training accuracy: 76.56%
# Total feedforward weight: 40117.29296875
# Total recurrent weight: 6.809651851654053
# Correlation of distance and weight matrices: -0.20642755478224875
#
# Epoch 58
# Training Loss: 4.10
# Training accuracy: 71.88%
# Total feedforward weight: 40334.53125
# Total recurrent weight: 6.807930946350098
# Correlation of distance and weight matrices: -0.20583443615113645
#
# Epoch 59
# Training Loss: 4.02
# Training accuracy: 70.31%
# Total feedforward weight: 40594.671875
# Total recurrent weight: 6.835208892822266
# Correlation of distance and weight matrices: -0.20637954953148346
#
# Epoch 60
# Training Loss: 4.14
# Training accuracy: 67.19%
# Total feedforward weight: 40894.2109375
# Total recurrent weight: 6.879922389984131
# Correlation of distance and weight matrices: -0.2062991213170091
#
# Epoch 61
# Training Loss: 4.06
# Training accuracy: 84.38%
# Total feedforward weight: 41167.3671875
# Total recurrent weight: 6.894631385803223
# Correlation of distance and weight matrices: -0.2069107914011263
#
# Epoch 62
# Training Loss: 4.07
# Training accuracy: 70.31%
# Total feedforward weight: 41392.8515625
# Total recurrent weight: 6.909294128417969
# Correlation of distance and weight matrices: -0.20728662588139235
#
# Epoch 63
# Training Loss: 4.07
# Training accuracy: 70.31%
# Total feedforward weight: 41617.84375
# Total recurrent weight: 6.897430419921875
# Correlation of distance and weight matrices: -0.20764157021009783
#
# Epoch 64
# Training Loss: 4.05
# Training accuracy: 75.00%
# Total feedforward weight: 41854.1953125
# Total recurrent weight: 6.9338788986206055
# Correlation of distance and weight matrices: -0.20756713974800334
#
# Epoch 65
# Training Loss: 4.03
# Training accuracy: 67.19%
# Total feedforward weight: 42107.484375
# Total recurrent weight: 6.9684062004089355
# Correlation of distance and weight matrices: -0.20794932912202754
#
# Epoch 66
# Training Loss: 4.14
# Training accuracy: 64.06%
# Total feedforward weight: 42448.2578125
# Total recurrent weight: 7.00899076461792
# Correlation of distance and weight matrices: -0.20835556373877118
#
# Epoch 67
# Training Loss: 4.11
# Training accuracy: 76.56%
# Total feedforward weight: 42752.43359375
# Total recurrent weight: 7.015018463134766
# Correlation of distance and weight matrices: -0.20841869226447068
#
# Epoch 68
# Training Loss: 4.04
# Training accuracy: 78.12%
# Total feedforward weight: 43080.53125
# Total recurrent weight: 7.041093826293945
# Correlation of distance and weight matrices: -0.20890384817357774
#
# Epoch 69
# Training Loss: 4.02
# Training accuracy: 81.25%
# Total feedforward weight: 43361.92578125
# Total recurrent weight: 7.06392765045166
# Correlation of distance and weight matrices: -0.20878317332309318
#
# Epoch 70
# Training Loss: 4.05
# Training accuracy: 82.81%
# Total feedforward weight: 43578.265625
# Total recurrent weight: 7.0811262130737305
# Correlation of distance and weight matrices: -0.20865485798485958
#
# Epoch 71
# Training Loss: 4.09
# Training accuracy: 78.12%
# Total feedforward weight: 43844.73828125
# Total recurrent weight: 7.118403434753418
# Correlation of distance and weight matrices: -0.20839914999311587
#
# Epoch 72
# Training Loss: 4.08
# Training accuracy: 67.19%
# Total feedforward weight: 44140.99609375
# Total recurrent weight: 7.12321662902832
# Correlation of distance and weight matrices: -0.2087823514311417
#
# Epoch 73
# Training Loss: 4.05
# Training accuracy: 76.56%
# Total feedforward weight: 44349.5234375
# Total recurrent weight: 7.138923645019531
# Correlation of distance and weight matrices: -0.20902691839741805
#
# Epoch 74
# Training Loss: 4.05
# Training accuracy: 71.88%
# Total feedforward weight: 44573.30859375
# Total recurrent weight: 7.132424354553223
# Correlation of distance and weight matrices: -0.20893335582305236
#
# Epoch 75
# Training Loss: 4.02
# Training accuracy: 76.56%
# Total feedforward weight: 44777.14453125
# Total recurrent weight: 7.176329612731934
# Correlation of distance and weight matrices: -0.2089088603120925
#
# Epoch 76
# Training Loss: 4.07
# Training accuracy: 75.00%
# Total feedforward weight: 44998.859375
# Total recurrent weight: 7.192161560058594
# Correlation of distance and weight matrices: -0.20914376741378382
#
# Epoch 77
# Training Loss: 4.10
# Training accuracy: 65.62%
# Total feedforward weight: 45265.796875
# Total recurrent weight: 7.196072101593018
# Correlation of distance and weight matrices: -0.20967308879429225
#
# Epoch 78
# Training Loss: 4.06
# Training accuracy: 71.88%
# Total feedforward weight: 45503.0625
# Total recurrent weight: 7.204611778259277
# Correlation of distance and weight matrices: -0.20990587879528305
#
# Epoch 79
# Training Loss: 4.06
# Training accuracy: 70.31%
# Total feedforward weight: 45676.578125
# Total recurrent weight: 7.211857795715332
# Correlation of distance and weight matrices: -0.2097798397668526
#
# Epoch 80
# Training Loss: 3.99
# Training accuracy: 82.81%
# Total feedforward weight: 45907.4765625
# Total recurrent weight: 7.254776954650879
# Correlation of distance and weight matrices: -0.21007914738228467
#
# Epoch 81
# Training Loss: 4.06
# Training accuracy: 75.00%
# Total feedforward weight: 46225.2109375
# Total recurrent weight: 7.277270317077637
# Correlation of distance and weight matrices: -0.2106931513950335
#
# Epoch 82
# Training Loss: 4.08
# Training accuracy: 71.88%
# Total feedforward weight: 46428.234375
# Total recurrent weight: 7.275271415710449
# Correlation of distance and weight matrices: -0.21067721691043273
#
# Epoch 83
# Training Loss: 4.04
# Training accuracy: 65.62%
# Total feedforward weight: 46596.265625
# Total recurrent weight: 7.279284477233887
# Correlation of distance and weight matrices: -0.2108239261382496
#
# Epoch 84
# Training Loss: 3.99
# Training accuracy: 75.00%
# Total feedforward weight: 46777.56640625
# Total recurrent weight: 7.295525550842285
# Correlation of distance and weight matrices: -0.21103306639430663
#
# Epoch 85
# Training Loss: 4.06
# Training accuracy: 78.12%
# Total feedforward weight: 46973.734375
# Total recurrent weight: 7.342381477355957
# Correlation of distance and weight matrices: -0.21129677202649746
#
# Epoch 86
# Training Loss: 4.07
# Training accuracy: 87.50%
# Total feedforward weight: 47188.0390625
# Total recurrent weight: 7.3427839279174805
# Correlation of distance and weight matrices: -0.21107483654604986
#
# Epoch 87
# Training Loss: 4.02
# Training accuracy: 79.69%
# Total feedforward weight: 47360.92578125
# Total recurrent weight: 7.353549957275391
# Correlation of distance and weight matrices: -0.2113151963805515
#
# Epoch 88
# Training Loss: 4.03
# Training accuracy: 89.06%
# Total feedforward weight: 47504.8359375
# Total recurrent weight: 7.337667942047119
# Correlation of distance and weight matrices: -0.21133984208538875
#
# Epoch 89
# Training Loss: 4.07
# Training accuracy: 67.19%
# Total feedforward weight: 47639.23046875
# Total recurrent weight: 7.350255966186523
# Correlation of distance and weight matrices: -0.2110497906838801
#
# Epoch 90
# Training Loss: 4.05
# Training accuracy: 73.44%
# Total feedforward weight: 47872.40625
# Total recurrent weight: 7.352482795715332
# Correlation of distance and weight matrices: -0.2108077450767578
#
# Epoch 91
# Training Loss: 4.07
# Training accuracy: 73.44%
# Total feedforward weight: 48236.2578125
# Total recurrent weight: 7.304506301879883
# Correlation of distance and weight matrices: -0.21026812394692773
#
# Epoch 92
# Training Loss: 4.13
# Training accuracy: 64.06%
# Total feedforward weight: 48568.06640625
# Total recurrent weight: 7.288691520690918
# Correlation of distance and weight matrices: -0.21038625306053724
#
# Epoch 93
# Training Loss: 4.07
# Training accuracy: 70.31%
# Total feedforward weight: 48847.734375
# Total recurrent weight: 7.266107559204102
# Correlation of distance and weight matrices: -0.21056666793639117
#
# Epoch 94
# Training Loss: 4.07
# Training accuracy: 62.50%
# Total feedforward weight: 49099.78515625
# Total recurrent weight: 7.298893451690674
# Correlation of distance and weight matrices: -0.2104171318827172
#
# Epoch 95
# Training Loss: 4.04
# Training accuracy: 75.00%
# Total feedforward weight: 49363.55078125
# Total recurrent weight: 7.312837600708008
# Correlation of distance and weight matrices: -0.21038699080638254
#
# Epoch 96
# Training Loss: 4.14
# Training accuracy: 60.94%
# Total feedforward weight: 49583.2890625
# Total recurrent weight: 7.353256702423096
# Correlation of distance and weight matrices: -0.21069037113621042
#
# Epoch 97
# Training Loss: 4.06
# Training accuracy: 81.25%
# Total feedforward weight: 49786.95703125
# Total recurrent weight: 7.361215114593506
# Correlation of distance and weight matrices: -0.21088846315879858
#
# Epoch 98
# Training Loss: 3.98
# Training accuracy: 81.25%
# Total feedforward weight: 50003.08203125
# Total recurrent weight: 7.374058723449707
# Correlation of distance and weight matrices: -0.21095983786875477
#
# Epoch 99
# Training Loss: 4.04
# Training accuracy: 78.12%
# Total feedforward weight: 50213.49609375
# Total recurrent weight: 7.37770414352417
# Correlation of distance and weight matrices: -0.21064097336830112

# %%
#Diagnostic: accuracy function -----

# x, y = outputs.sum(dim=0).max(1)
# print(y)
# print(targets)
# accuracy = np.mean((targets == y).detach().cpu().numpy())
# print(accuracy)

# %%
#Test set accuracy -----

total = 0
correct = 0
dataloader = testloader

with torch.no_grad():
  net.eval()
  for data, targets in dataloader:
    data = data.to(device)
    targets = targets.to(device)

    #Forward pass
    test_spk, _ = net(data)

    #Calculate total accuracy
    _, predicted = test_spk.sum(dim=0).max(1)
    total += targets.size(0)
    correct += (predicted == targets).sum().item()

print(f"Total correctly classified test set images: {correct}/{total}")
print(f"Test Set Accuracy: {100 * correct / total:.2f}%")
# Out:
# Total correctly classified test set images: 158/256
# Test Set Accuracy: 61.72%

# %%
#Model visualizations (post-training) -----

#All layers and associated parameters
for name, param in net.named_parameters():
    print(f"Layer: {name} | Size: {param.size()} | Values : {param} \n")

#Membrane time constant distribution
#Define plot + parameters
tau = (-time_step / np.log(net.lif1.beta.data.cpu())) / 1e-3
fig, ax = plt.subplots()
tc_distribution = sns.histplot(data = tau, kde = False, ax = ax, binwidth = 3)

#Visual modifications
ax.axes.get_yaxis().set_visible(False)
plt.xlabel('ms')
# Out:
# Layer: fc1.weight | Size: torch.Size([100, 32768]) | Values : Parameter containing:
# tensor([[ 0.0114,  0.0320, -0.0065,  ...,  0.0120, -0.0243,  0.0093],
#         [-0.0196, -0.0067, -0.0079,  ..., -0.0024, -0.0057,  0.0151],
#         [-0.0101,  0.0004, -0.0044,  ..., -0.0079, -0.0057,  0.0216],
#         ...,
#         [-0.0153,  0.0184,  0.0070,  ...,  0.0070,  0.0032,  0.0036],
#         [ 0.0021,  0.0076, -0.0037,  ..., -0.0044, -0.0014,  0.0005],
#         [ 0.0047,  0.0330,  0.0093,  ..., -0.0085, -0.0053,  0.0100]],
#        device='cuda:0', requires_grad=True)
#
# Layer: fc1.bias | Size: torch.Size([100]) | Values : Parameter containing:
# tensor([ 0.0146,  0.0738, -0.0093, -0.0479, -0.0788, -0.0644,  0.1330, -0.0287,
#          0.0078,  0.0377,  0.0262, -0.0072, -0.0291, -0.0043, -0.0008,  0.0840,
#          0.0434, -0.0236, -0.0129, -0.0281,  0.0023,  0.0522, -0.0005,  0.0408,
#         -0.0050, -0.0302,  0.0030, -0.0179, -0.0074,  0.0849,  0.0140,  0.0164,
#         -0.0091, -0.0358, -0.0431,  0.0277,  0.0102,  0.0190,  0.0423, -0.0682,
#         -0.0040, -0.0034, -0.0460,  0.0589,  0.0585, -0.0038,  0.1215, -0.0129,
#          0.0679, -0.0069, -0.0279,  0.0023,  0.0040, -0.0111, -0.0145, -0.0375,
#          0.0021,  0.0568,  0.0433, -0.0029,  0.0266, -0.0145,  0.0241,  0.0179,
#          0.0393,  0.0987, -0.0139,  0.0661,  0.0825, -0.0322, -0.0271,  0.0440,
#         -0.0183, -0.0120,  0.0733, -0.0063,  0.0587, -0.0024,  0.0868, -0.0177,
#          0.0531, -0.0106,  0.0284,  0.0065, -0.1465,  0.1217, -0.0192,  0.0187,
#          0.0035,  0.0968, -0.0835,  0.1118,  0.0217,  0.0524, -0.0075, -0.0323,
#          0.0453, -0.1070,  0.0509,  0.0784], device='cuda:0',
#        requires_grad=True)
#
# Layer: lif1.beta | Size: torch.Size([100]) | Values : Parameter containing:
# tensor([0.9450, 0.9409, 0.9803, 0.8971, 0.9011, 0.9499, 0.9509, 0.9950, 0.9459,
#         0.9801, 0.9161, 0.9720, 0.9750, 0.9706, 0.9925, 0.9138, 0.9866, 0.9754,
#         0.9333, 0.9133, 0.9681, 0.9942, 0.9479, 0.9632, 0.9597, 0.9117, 0.9011,
#         0.9946, 0.9162, 0.9942, 0.7646, 0.9475, 0.9011, 0.9638, 0.9845, 0.9258,
#         0.9530, 0.9673, 0.9459, 0.9879, 0.9611, 0.9619, 0.9393, 0.9932, 0.9660,
#         0.9899, 0.9283, 0.9745, 0.9950, 0.9189, 0.9244, 0.9481, 0.9622, 0.9565,
#         0.9946, 0.9581, 0.9284, 0.9521, 0.9945, 0.9462, 0.9814, 0.9425, 0.8942,
#         0.9725, 0.9950, 0.9615, 0.9832, 0.9808, 0.9886, 0.8442, 0.9491, 0.9950,
#         0.9950, 0.9437, 0.7683, 0.9551, 0.9863, 0.9610, 0.9726, 0.9703, 0.9356,
#         0.9340, 0.9838, 0.9617, 0.9568, 0.8619, 0.8979, 0.9442, 0.9507, 0.9764,
#         0.9443, 0.9327, 0.8758, 0.8852, 0.8604, 0.8816, 0.9706, 0.9093, 0.9947,
#         0.9764], device='cuda:0', dtype=torch.float64, requires_grad=True)
#
# Layer: lif1.recurrent.weight | Size: torch.Size([100, 100]) | Values : Parameter containing:
# tensor([[-2.2674e-02,  5.2017e-06,  1.0275e-04,  ..., -1.9511e-04,
#          -2.6310e-04, -1.3024e-05],
#         [-1.9819e-04,  5.8344e-03,  1.8438e-04,  ...,  5.6586e-05,
#          -9.1113e-07, -1.6681e-04],
#         [-1.2268e-04, -6.2097e-05,  2.4562e-02,  ..., -4.0200e-05,
#          -1.4591e-04, -5.8619e-05],
#         ...,
#         [-1.5023e-04,  7.5449e-05, -2.8084e-04,  ..., -4.7322e-02,
#          -1.5626e-04, -9.6279e-05],
#         [-7.5877e-05,  2.9894e-05, -3.2559e-05,  ..., -6.7920e-05,
#          -1.1193e-02,  3.9553e-05],
#         [ 5.5808e-05, -2.7430e-06, -4.5264e-05,  ..., -1.8322e-04,
#          -4.4679e-04,  3.5431e-02]], device='cuda:0', requires_grad=True)
#
# Layer: lif1.recurrent.bias | Size: torch.Size([100]) | Values : Parameter containing:
# tensor([-0.0435,  0.1004, -0.0582, -0.0082, -0.1676, -0.1162,  0.1325,  0.0506,
#         -0.0296,  0.0999, -0.0553, -0.0676, -0.0367, -0.0998,  0.0454,  0.1126,
#          0.0281,  0.0669, -0.0375,  0.0250, -0.0432,  0.0699,  0.0843,  0.0948,
#          0.0229, -0.1004, -0.0009, -0.0133,  0.0255,  0.1722,  0.0510,  0.1014,
#         -0.0760, -0.0517, -0.1330,  0.0752, -0.0803,  0.0181,  0.0800, -0.1472,
#         -0.0561,  0.0068,  0.0432, -0.0070,  0.1008,  0.0076,  0.0838,  0.0122,
#          0.0158, -0.0437, -0.0912,  0.0172, -0.0766, -0.1158, -0.1172,  0.0252,
#          0.0040,  0.1488,  0.0585,  0.0863, -0.0676, -0.0523,  0.0326,  0.0597,
#         -0.0022,  0.1632,  0.0500,  0.0109,  0.1106, -0.1001, -0.0913,  0.0224,
#         -0.1082, -0.0683,  0.1568, -0.0313, -0.0423,  0.0937,  0.1209, -0.0735,
#          0.1086,  0.0149,  0.1073, -0.0284, -0.2089,  0.1195, -0.1147,  0.0510,
#          0.0078,  0.0190, -0.1762,  0.1806,  0.0183,  0.0610,  0.0584,  0.0564,
#         -0.0348, -0.1253,  0.0112,  0.0336], device='cuda:0',
#        requires_grad=True)
#
# Layer: fc2.weight | Size: torch.Size([11, 100]) | Values : Parameter containing:
# tensor([[-0.0114, -0.0482, -0.0101,  ..., -0.0927,  0.0695,  0.0527],
#         [ 0.0004,  0.0275,  0.0926,  ...,  0.0095,  0.0042,  0.0084],
#         [ 0.0190,  0.0692, -0.0114,  ..., -0.0162,  0.0709, -0.0150],
#         ...,
#         [-0.0478, -0.0144,  0.0257,  ...,  0.2474, -0.0473,  0.0032],
#         [-0.0570, -0.0522,  0.0692,  ...,  0.0212,  0.0378, -0.1322],
#         [-0.0093,  0.0485, -0.0370,  ..., -0.0769,  0.0568,  0.0287]],
#        device='cuda:0', requires_grad=True)
#
# Layer: fc2.bias | Size: torch.Size([11]) | Values : Parameter containing:
# tensor([ 0.0165,  0.0132, -0.0102,  0.0149,  0.0249,  0.1093,  0.0228, -0.1057,
#         -0.0175,  0.0796, -0.0097], device='cuda:0', requires_grad=True)
# Text(0.5, 0, 'ms')

# %%
feed_tot_hist = torch.FloatTensor(feed_tot_hist)
rec_tot_hist = torch.FloatTensor(rec_tot_hist)
corr_hist = torch.FloatTensor(corr_hist)

# %%
#Data visualizations -----

#Loss
plt.figure(figsize=(3.3,2),dpi=150)
plt.plot(loss_hist)
plt.xlabel('Training iterations')
plt.ylabel('Training loss')
plt.savefig('training_loss')

#Accuracy/performance
plt.figure(figsize=(3.3,2),dpi=150)
plt.plot(acc_hist)
plt.xlabel('Epoch')
plt.ylabel('Training accuracy')
plt.savefig('training_accuracy')

#Total feedforward weight
plt.figure(figsize=(3.3,2),dpi=150)
plt.plot(feed_tot_hist)
plt.xlabel('Epoch')
plt.ylabel('Total feedforward weight')
plt.savefig('total_feedforward_weight')

#Total recurrent weight
plt.figure(figsize=(3.3,2),dpi=150)
plt.plot(rec_tot_hist.cpu())
plt.xlabel('Epoch')
plt.ylabel('Total recurrent weight')
plt.savefig('total_recurrent_weight')

#Correlation of distance/weight matrices
plt.figure(figsize=(3.3,2),dpi=150)
plt.plot(corr_hist.cpu())
plt.xlabel('Epoch')
plt.ylabel('Corr(distance, weight)')
plt.savefig('correlation')
